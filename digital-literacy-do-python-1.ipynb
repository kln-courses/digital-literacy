# %% [markdown]
# # Digital Literacy Do Python 1 #
#
# I document my code here and there

# %% [markdown]
# Import **Numpy** module and use *function* to read csv file in data directory

# %%
import numpy as np

data = np.loadtxt(fname="data/inflammation-01.csv", delimiter=",")
print(data.shape)
# Out:
# (60, 40)

# %% [markdown]
# ## Lesson 1: Analyzing patient data ##

# %%
weight_kg = 55
patient = "John"

# %%
print(weight_kg)
print("weight in pounds for {} is {}".format(patient,round(2.2*weight_kg,2)))
# Out:
# 55
# weight in pounds for John is 121.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
img = plt.imshow(data)
plt.show(img)

# %% [markdown]
# ### Indexing matrix/tabular data/arrays ###

# %%
print("the first value {}".format(data[0,0]))
print("the middle value is {}".format(data[30,20]))
print(data[0:4,0:10])
# Out:
# the first value 0.0
# the middle value is 13.0
# [[0. 0. 1. 3. 1. 2. 4. 7. 8. 3.]
#  [0. 1. 2. 1. 2. 1. 3. 2. 2. 6.]
#  [0. 1. 1. 3. 3. 2. 6. 2. 5. 9.]
#  [0. 0. 2. 0. 4. 2. 2. 1. 6. 7.]]

# %% [markdown]
# arithemetics with matrices

# %%
doubledata = data*2
print(doubledata[0:4,0:10])
# Out:
# [[ 0.  0.  2.  6.  2.  4.  8. 14. 16.  6.]
#  [ 0.  2.  4.  2.  4.  2.  6.  4.  4. 12.]
#  [ 0.  2.  2.  6.  6.  4. 12.  4. 10. 18.]
#  [ 0.  0.  4.  0.  8.  4.  4.  2. 12. 14.]]

# %% [markdown]
# basic modeling with arrays

# %%
maxval = np.max(data,axis=0)
#print(maxval)
minval = np.min(data,axis=0)
#print(minval)
print(np.mean(data))
print(np.std(data))
# Out:
# 6.14875
# 4.613833197118566

# %%
fig = plt.figure(figsize=(10.,3.))

axes1 = fig.add_subplot(1,3,1)
axes2 = fig.add_subplot(1,3,2)
axes3 = fig.add_subplot(1,3,3)

axes1.set_ylabel("Average")
axes1.plot(np.mean(data,axis=0),color="red")

axes2.set_ylabel("Maximum")
axes2.plot(np.max(data,axis=0))

axes3.set_ylabel("Minimum")
axes3.plot(np.min(data,axis=0))

plt.tight_layout()
#plt.show()
plt.savefig(fname="figures/meanmaxmin_1.png",dpi=300)

# %% [markdown]
# ## Repeating actions with loops ##

# %%
word = "mind"
print(word)
print(len(word))

print(word[0])
print(word[1])
print(word[2])
print(word[3])
# Out:
# mind
# 4
# m
# i
# n
# d

# %% [markdown]
# scale with loop

# %%
for char in word:
    print(char)
# Out:
# d
# d
# d
# d

# %%
tolkien_list = ["Hobbit.txt","Dragon.txt","Ring.txt"]
result_list = []
for word in tolkien_list:
    word_norm = word.lower()
    word_norm = word_norm.split(".")[0]
    #print(word_norm)
    result_list.append(word_norm)
    
print(result_list)
# Out:
# ['hobbit', 'dragon', 'ring']

# %%
word = "Darth Vader"
word_backwards = str()

idx = 0
for char in word:
    #print(char)
    word_backwards = char + word_backwards
    print(idx,word_backwards)
    idx = idx + 1
print()
print("Resulting word is{}".format(word_backwards))
# Out:
# 0 D
# 1 aD
# 2 raD
# 3 traD
# 4 htraD
# 5  htraD
# 6 V htraD
# 7 aV htraD
# 8 daV htraD
# 9 edaV htraD
# 10 redaV htraD
#
# Resulting word isredaV htraD

# %% [markdown]
# ## Analyzing data from multiple files

# %%
import glob
print(glob.glob("data/inflammation*.csv"))
# Out:
# ['data/inflammation-07.csv', 'data/inflammation-08.csv', 'data/inflammation-11.csv', 'data/inflammation-05.csv', 'data/inflammation-10.csv', 'data/inflammation-04.csv', 'data/inflammation-03.csv', 'data/inflammation-09.csv', 'data/inflammation-06.csv', 'data/inflammation-01.csv', 'data/inflammation-12.csv', 'data/inflammation-02.csv']

# %%
filenames = sorted(glob.glob("data/inflammation*.csv"))

idx = 1# index for continous file naming
for filename in filenames:
    data = np.loadtxt(fname=filename, delimiter=",")
    
    fig = plt.figure(figsize=(10.,3.))

    axes1 = fig.add_subplot(1,3,1)
    axes2 = fig.add_subplot(1,3,2)
    axes3 = fig.add_subplot(1,3,3)

    axes1.set_ylabel("Average")
    axes1.plot(np.mean(data,axis=0),color="red")

    axes2.set_ylabel("Maximum")
    axes2.plot(np.max(data,axis=0))

    axes3.set_ylabel("Minimum")
    axes3.plot(np.min(data,axis=0))

    plt.tight_layout()
    plt.savefig(fname="figures/meanmaxmin_{}.png".format(idx))
    idx = idx + 1# update index
